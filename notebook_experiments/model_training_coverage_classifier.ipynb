# %%
#pip install torch --index-url https://download.pytorch.org/whl/cu118
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split


data = pd.read_csv("../data/model_data.csv")

# %%
home_surfaces = data[[i for i in data.columns if ('surface_' in i)&('away_' not in i)]].copy()
away_surfaces = data[[i for i in data.columns if ('surface_' in i)&('away_' in i)]].copy()

surface_interactions = pd.DataFrame()
for col in home_surfaces.columns:
    for acol in away_surfaces.columns:
        surface_interactions[f"{col}*{acol}"] = (
            home_surfaces[col]*away_surfaces[acol]
        )

sit = surface_interactions.T

surface_interactions = sit[sit.sum(axis=1)>30].T

data[list(surface_interactions.columns)] = surface_interactions

data['coverage_flg'] = np.where(data['coverage']>0,1,0)

# %%
this_season = data[data['season']==2023].copy()

model_data = data[data['season']<2023].copy()
model_data = model_data[model_data['coverage']!=0].copy()

exclusions = ['away_team','home_team','away_score','home_score','result','season','coverage','coverage_flg']

first_features = [
    i for i in model_data.columns if 
    (i not in exclusions)&
    ('_team_id_' not in i)&
    ('2pt' not in i)
]
target = 'coverage_flg'
spread = 'spread_line'
result = 'result'

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(model_data[first_features],model_data[target],
                                           test_size=.1,random_state=42,shuffle=True)

# %%
corr = pd.concat([Xtrain,ytrain],axis=1).corr(numeric_only=True,method='pearson')[target].sort_values()
corr.sort_values(ascending=False)
feats_used = corr[(abs(corr)>.038)&(abs(corr)<1)]
features = [i for i in feats_used.index if i != target]

# %%
model_data[['home_cumemeanpoints_scored_shift1','home_cumemeanpoints_allowed_shift1',
            'away_cumemeanpoints_scored_shift1','away_cumemeanpoints_allowed_shift1',
            'cumemeanpoints_allowed_diff','cumemeanpoints_scored_diff',
            'away_offense_power','home_offense_power',
            'coverage_flg'
            ]].corr()['coverage_flg']
# Out:
# home_cumemeanpoints_scored_shift1    -0.020936
# home_cumemeanpoints_allowed_shift1    0.013423
# away_cumemeanpoints_scored_shift1     0.015886
# away_cumemeanpoints_allowed_shift1   -0.039493
# cumemeanpoints_allowed_diff           0.056527
# cumemeanpoints_scored_diff           -0.038419
# away_offense_power                    0.003151
# home_offense_power                    0.016625
# coverage_flg                          1.000000
# Name: coverage_flg, dtype: float64

# %%
pd.set_option("display.max_rows",164)
corr.sort_values(ascending=False)
# Out:
# coverage_flg                                1.000000
# home_pacr                                   0.052029
# week                                        0.050180
# home_receiving_fumbles                      0.050001
# away_cumemeanresult_shift1                  0.047333
# home_receiving_tds                          0.043258
# away_fantasy_points                         0.043080
# surface_matrixturf                          0.042944
# away_rushing_epa                            0.042569
# diff_sack_fumbles_lost                      0.042173
# cumemeanpoints_allowed_diff                 0.041616
# surface_matrixturf*away_surface_grass       0.039669
# away_rushing_fumbles                        0.038733
# diff_receiving_fumbles                      0.036003
# away_surface_grass                          0.034810
# away_receiving_air_yards                    0.034297
# home_carries                                0.033915
# away_fantasy_points_ppr                     0.033844
# home_rushing_yards                          0.032190
# away_rushing_first_downs                    0.031909
# diff_pacr                                   0.030970
# away_wopr                                   0.030594
# away_target_share                           0.029810
# diff_sack_fumbles                           0.029465
# away_rushing_yards                          0.026184
# diff_sack_yards                             0.026105
# away_air_yards_share                        0.024418
# surface_grass*away_surface_grass            0.023453
# diff_receiving_tds                          0.023233
# away_special_teams_tds                      0.022991
# away_rushing_fumbles_lost                   0.022911
# home_receiving_fumbles_lost                 0.022642
# home_passing_epa                            0.022180
# diff_receiving_yards_after_catch            0.021270
# home_receiving_yards_after_catch            0.020719
# roof_outdoors                               0.020403
# away_carries                                0.019326
# away_receiving_fumbles_lost                 0.017667
# roof_dome                                   0.016884
# diff_racr                                   0.016765
# diff_sacks                                  0.015644
# surface_grass                               0.015313
# away_cumemeanpoints_scored_shift1           0.014982
# home_passing_tds                            0.014807
# diff_passing_tds                            0.014398
# home_fantasy_points_ppr                     0.014164
# home_fantasy_points                         0.014105
# diff_receiving_first_downs                  0.013990
# home_rushing_epa                            0.012765
# diff_passing_epa                            0.012738
# home_rushing_first_downs                    0.012326
# away_receiving_tds                          0.011917
# away_targets                                0.011104
# away_receiving_yards                        0.011058
# away_offense_power                          0.010760
# away_roof_outdoors                          0.010289
# diff_carries                                0.010096
# surface_grass*away_surface_fieldturf        0.009657
# away_pacr                                   0.009481
# away_surface_fieldturf                      0.008154
# away_rushing_tds                            0.007654
# surface_fieldturf*away_surface_grass        0.007225
# away_passing_air_yards                      0.006673
# diff_passing_yards_after_catch              0.006659
# home_receiving_first_downs                  0.006427
# home_rushing_fumbles                        0.006299
# home_sack_yards                             0.006144
# home_cumemeanpoints_allowed_shift1          0.005269
# diff_receiving_epa                          0.005007
# away_passing_epa                            0.004813
# surface_astroturf*away_surface_grass        0.004618
# diff_rushing_yards                          0.004266
# surface_astroturf                           0.004244
# home_racr                                   0.004008
# away_receptions                             0.003119
# home_receiving_epa                          0.002421
# home_targets                                0.002189
# away_interceptions                          0.002032
# surface_grass*away_surface_sportturf        0.001754
# away_surface_sportturf                      0.001527
# home_offense_power                          0.000714
# surface_grass*away_surface_matrixturf       0.000037
# home_target_share                          -0.000393
# home_interceptions                         -0.000526
# diff_receiving_fumbles_lost                -0.000636
# home_sacks                                 -0.001551
# away_passing_tds                           -0.002195
# home_receptions                            -0.002678
# home_receiving_yards                       -0.002690
# diff_receptions                            -0.003992
# home_receiving_air_yards                   -0.004120
# away_receiving_epa                         -0.004541
# home_wopr                                  -0.004900
# diff_interceptions                         -0.005637
# home_sack_fumbles                          -0.005927
# diff_targets                               -0.006221
# away_receiving_fumbles                     -0.007063
# surface_fieldturf*away_surface_fieldturf   -0.007685
# away_completions                           -0.007814
# away_roof_open                             -0.008317
# diff_games                                 -0.008398
# away_attempts                              -0.008415
# away_passing_first_downs                   -0.009156
# away_receiving_yards_after_catch           -0.009437
# away_passing_yards                         -0.009516
# diff_receiving_yards                       -0.009550
# home_passing_yards_after_catch             -0.009648
# away_games                                 -0.009663
# diff_passing_first_downs                   -0.010684
# surface_sportturf*away_surface_grass       -0.013121
# away_receiving_first_downs                 -0.013602
# diff_rushing_first_downs                   -0.013620
# away_roof_dome                             -0.014036
# diff_fantasy_points_ppr                    -0.014154
# home_air_yards_share                       -0.014695
# diff_passing_yards                         -0.015438
# home_rushing_fumbles_lost                  -0.018551
# away_passing_yards_after_catch             -0.018962
# away_racr                                  -0.020553
# diff_fantasy_points                        -0.020935
# diff_target_share                          -0.021081
# diff_rushing_epa                           -0.021422
# home_special_teams_tds                     -0.021763
# home_games                                 -0.021830
# roof_open                                  -0.022491
# surface_fieldturf                          -0.022542
# diff_completions                           -0.023102
# home_passing_first_downs                   -0.024037
# diff_rushing_fumbles_lost                  -0.024812
# diff_wopr                                  -0.024880
# surface_sportturf                          -0.025039
# diff_rushing_fumbles                       -0.025920
# diff_rushing_tds                           -0.025964
# home_sack_fumbles_lost                     -0.026642
# diff_air_yards_share                       -0.027360
# diff_receiving_air_yards                   -0.027437
# away_sacks                                 -0.028044
# home_rushing_tds                           -0.029235
# home_cumemeanpoints_scored_shift1          -0.030793
# away_sack_yards                            -0.031109
# home_passing_yards                         -0.031165
# away_cumemeanpoints_allowed_shift1         -0.033426
# diff_attempts                              -0.034443
# home_cumemeanresult_shift1                 -0.036275
# away_sack_fumbles                          -0.036281
# home_completions                           -0.040251
# diff_passing_air_yards                     -0.040616
# spread_line                                -0.040852
# away_surface_matrixturf                    -0.043677
# diff_special_teams_tds                     -0.045583
# cumemeanpoints_scored_diff                 -0.048048
# home_passing_air_yards                     -0.049033
# away_surface_astroturf                     -0.053055
# home_attempts                              -0.055566
# surface_grass*away_surface_astroturf       -0.056455
# cumemeanresult_diff                        -0.060448
# away_sack_fumbles_lost                     -0.069384
# surface_astroplay                                NaN
# surface_dessograss                               NaN
# away_surface_astroplay                           NaN
# away_surface_dessograss                          NaN
# Name: coverage_flg, dtype: float64

# %%
features
# Out:
# ['away_sack_fumbles_lost',
#  'cumemeanresult_diff',
#  'surface_grass*away_surface_astroturf',
#  'home_attempts',
#  'away_surface_astroturf',
#  'home_passing_air_yards',
#  'cumemeanpoints_scored_diff',
#  'diff_special_teams_tds',
#  'away_surface_matrixturf',
#  'spread_line',
#  'diff_passing_air_yards',
#  'home_completions',
#  'away_rushing_fumbles',
#  'surface_matrixturf*away_surface_grass',
#  'cumemeanpoints_allowed_diff',
#  'diff_sack_fumbles_lost',
#  'away_rushing_epa',
#  'surface_matrixturf',
#  'away_fantasy_points',
#  'home_receiving_tds',
#  'away_cumemeanresult_shift1',
#  'home_receiving_fumbles',
#  'week',
#  'home_pacr']

# %%
ytrain.mean()
# Out:
# 0.47717842323651455

# %%
Xtrain,Xtest,ytrain,ytest,strain,stest=train_test_split(
    model_data[features],model_data[target],
    ((model_data['season']-min(model_data['season']))/(max(model_data['season'])-min(model_data['season'])))*0+1,
    test_size=.2,random_state=42,shuffle=True)

# %%
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures


from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SequentialFeatureSelector

from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier


from sklearn.impute import KNNImputer

# %%
inner = SGDClassifier(loss='perceptron',penalty='l2',alpha=.0001,
                      fit_intercept=False,
                      early_stopping=True,shuffle=True,
                      validation_fraction=.1,n_iter_no_change=26,random_state=42)


inner = KNeighborsClassifier(n_neighbors=15,weights='uniform')
#inner = RandomForestClassifier(random_state=42,n_estimators=35,max_depth=6,min_samples_leaf=5)
#inner = SVC(C=1,kernel='rbf',)
model = Pipeline(steps=[
    #('imputer',KNNImputer(n_neighbors=5)),
    ('poly',PolynomialFeatures(degree=2,interaction_only=False,include_bias=True)),
    ('VarianceThreshold',VarianceThreshold()),
    ('scaler',StandardScaler()),
    ('selector',SelectKBest(k=45)),
    ('selector2',SequentialFeatureSelector(estimator=inner,n_features_to_select=5,n_jobs=-1)),
    ('learner',inner
    )
]).fit(Xtrain.fillna(0),ytrain)#,learner__sample_weight=strain)

coverage_flg_pred = pd.Series(model.predict(Xtest.fillna(0)),Xtest.index)
coverage_flg_fit = pd.Series(model.predict(Xtrain.fillna(0)),Xtrain.index)

# %%
print("Training: ")
result = pd.DataFrame()
result[target] = ytrain
result[target+'_pred'] = coverage_flg_fit

result['outcome'] = np.where(
    (result['coverage_flg']==0)&(result['coverage_flg_pred']==0),'TN',
    np.where(
    (result['coverage_flg']==1)&(result['coverage_flg_pred']==1),'TP',
    np.where(
    (result['coverage_flg']==1)&(result['coverage_flg_pred']==0),'FN','FP')))

result['correct'] = np.where(result['outcome'].str[0]=='T','T','F')
result['cnt']=1
conf = result.groupby(['outcome'])['cnt'].sum()
acc = result.groupby(['correct'])['cnt'].sum()

if 'FN' in conf.index:
    print(conf)
    print(acc)
    print('recall: ',conf['TP']/(conf['TP']+conf['FN']))
    print('precision: ',conf['TP']/(conf['TP']+conf['FP']))
    print('selectivity: ',conf['TN']/(conf['TN']+conf['FP']))
    print('neg pred val: ',conf['TN']/(conf['TN']+conf['FN']))
    print('accuracy: ',acc['T']/(acc['T']+acc['F']))

print("Test: ")
result = pd.DataFrame()
result[target] = ytest
result[target+'_pred'] = coverage_flg_pred

result['outcome'] = np.where(
    (result['coverage_flg']==0)&(result['coverage_flg_pred']==0),'TN',
    np.where(
    (result['coverage_flg']==1)&(result['coverage_flg_pred']==1),'TP',
    np.where(
    (result['coverage_flg']==1)&(result['coverage_flg_pred']==0),'FN','FP')))
result['correct'] = np.where(result['outcome'].str[0]=='T','T','F')
result['cnt']=1
conf = result.groupby(['outcome'])['cnt'].sum()
acc = result.groupby(['correct'])['cnt'].sum()
print(conf)
print(acc)
print('recall: ',conf['TP']/(conf['TP']+conf['FN']))
print('precision: ',conf['TP']/(conf['TP']+conf['FP']))
print('selectivity: ',conf['TN']/(conf['TN']+conf['FP']))
print('neg pred val: ',conf['TN']/(conf['TN']+conf['FN']))
print('accuracy: ',acc['T']/(acc['T']+acc['F']))
# Out:
# Training:
# outcome
# FN    231
# FP    162
# TN    398
# TP    280
# Name: cnt, dtype: int64
# correct
# F    393
# T    678
# Name: cnt, dtype: int64
# recall:  0.547945205479452
# precision:  0.6334841628959276
# selectivity:  0.7107142857142857
# neg pred val:  0.6327503974562798
# accuracy:  0.6330532212885154
# Test:
# outcome
# FN    63
# FP    61
# TN    79
# TP    65
# Name: cnt, dtype: int64
# correct
# F    124
# T    144
# Name: cnt, dtype: int64
# recall:  0.5078125
# precision:  0.5158730158730159
# selectivity:  0.5642857142857143
# neg pred val:  0.5563380281690141
# accuracy:  0.5373134328358209

# %%
allY = pd.concat([ytrain,ytest])
allX = pd.concat([Xtrain,Xtest])

model.fit(allX.fillna(0),allY)
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures()),
#                 ('VarianceThreshold', VarianceThreshold()),
#                 ('scaler', StandardScaler()), ('selector', SelectKBest(k=45)),
#                 ('selector2',
#                  SequentialFeatureSelector(estimator=KNeighborsClassifier(n_neighbors=15),
#                                            n_features_to_select=5, n_jobs=-1)),
#                 ('learner', KNeighborsClassifier(n_neighbors=15))])

# %%
result.mean(numeric_only=True)
# Out:
# coverage_flg         0.477612
# coverage_flg_pred    0.470149
# cnt                  1.000000
# dtype: float64

# %%
this_seasonX = this_season[features].copy()
this_season_coverage_flg_prediction = pd.Series(
    model.predict(this_seasonX.fillna(0)),
    this_seasonX.index)
this_season['coverage_flg_pred'] = this_season_coverage_flg_prediction
this_season['_correct']=np.where(this_season['coverage_flg']==this_season['coverage_flg_pred'],1,0)

# %%
this_season[this_season['week']==1][['away_team','home_team','coverage_flg_pred','coverage_flg','_correct']]
# Out:
#      away_team home_team  coverage_flg_pred  coverage_flg  _correct
# 1372       DET        KC                  0             0         1
# 1373       CAR       ATL                  0             1         0
# 1374       HOU       BAL                  0             1         0
# 1375       CIN       CLE                  0             1         0
# 1376       JAX       IND                  0             0         1
# 1377        TB       MIN                  0             0         1
# 1378       TEN        NO                  0             0         1
# 1379        SF       PIT                  0             0         1
# 1380       ARI       WAS                  0             0         1
# 1381        GB       CHI                  0             0         1
# 1382        LV       DEN                  0             0         1
# 1383       MIA       LAC                  0             0         1
# 1384       PHI        NE                  0             0         1
# 1385        LA       SEA                  0             0         1
# 1386       DAL       NYG                  0             0         1
# 1387       BUF       NYJ                  0             1         0

# %%
this_season[this_season['week']==2][['away_team','home_team','coverage_flg_pred','coverage_flg','_correct']]
# Out:
#      away_team home_team  coverage_flg_pred  coverage_flg  _correct
# 1388       MIN       PHI                  0             0         1
# 1389        GB       ATL                  0             0         1
# 1390        LV       BUF                  0             1         0
# 1391       BAL       CIN                  0             0         1
# 1392       SEA       DET                  0             0         1
# 1393       IND       HOU                  0             0         1
# 1394        KC       JAX                  0             0         1
# 1395       CHI        TB                  0             1         0
# 1396       LAC       TEN                  0             1         0
# 1397       NYG       ARI                  0             1         0
# 1398        SF        LA                  1             1         1
# 1399       NYJ       DAL                  0             1         0
# 1400       WAS       DEN                  0             0         1
# 1401       MIA        NE                  1             0         0
# 1402        NO       CAR                  0             0         1
# 1403       CLE       PIT                  0             1         0

# %%
this_season[this_season['week']==3][['away_team','home_team','coverage_flg_pred','coverage_flg','_correct']]
# Out:
#      away_team home_team  coverage_flg_pred  coverage_flg  _correct
# 1404       NYG        SF                  0             1         0
# 1405       IND       BAL                  0             0         1
# 1406       TEN       CLE                  1             1         1
# 1407       ATL       DET                  0             1         0
# 1408        NO        GB                  0             1         0
# 1409       HOU       JAX                  0             0         1
# 1410       DEN       MIA                  0             1         0
# 1411       LAC       MIN                  0             0         1
# 1412        NE       NYJ                  0             0         1
# 1413       BUF       WAS                  0             0         1
# 1414       CAR       SEA                  1             1         1
# 1415       DAL       ARI                  1             1         1
# 1416       CHI        KC                  0             1         0
# 1417       PIT        LV                  0             0         1
# 1418       PHI        TB                  1             0         0
# 1419        LA       CIN                  0             0         1

# %%
this_season[this_season['week']==4][['away_team','home_team','coverage_flg_pred','coverage_flg','_correct']]
# Out:
#      away_team home_team  coverage_flg_pred  coverage_flg  _correct
# 1420       DET        GB                  1             0         0
# 1421       ATL       JAX                  0             1         0
# 1422       MIA       BUF                  1             1         1
# 1423       MIN       CAR                  0             0         1
# 1424       DEN       CHI                  0             0         1
# 1425       BAL       CLE                  1             0         0
# 1426       PIT       HOU                  0             1         0
# 1427        LA       IND                  1             0         0
# 1428        TB        NO                  0             0         1
# 1429       WAS       PHI                  0             0         1
# 1430       CIN       TEN                  0             1         0
# 1431        LV       LAC                  0             0         1
# 1432        NE       DAL                  1             1         1
# 1433       ARI        SF                  1             1         1
# 1434        KC       NYJ                  0             1         0
# 1435       SEA       NYG                  1             0         0

# %%
this_season[this_season['week']==5][['away_team','home_team','coverage_flg_pred','spread_line','coverage_flg','_correct']]
# Out:
#      away_team home_team  coverage_flg_pred  spread_line  coverage_flg  \
# 1436       CHI       WAS                  0          6.0             0
# 1437       JAX       BUF                  0          5.5             0
# 1438       HOU       ATL                  0          2.5             0
# 1439       CAR       DET                  0          9.5             1
# 1440       TEN       IND                  0         -2.5             1
# 1441       NYG       MIA                  0         12.5             1
# 1442        NO        NE                  0          2.5             0
# 1443       BAL       PIT                  0         -4.5             1
# 1444       CIN       ARI                  1         -3.0             0
# 1445       PHI        LA                  0         -3.5             0
# 1446       NYJ       DEN                  0          2.5             0
# 1447        KC       MIN                  0         -3.5             0
# 1448       DAL        SF                  0          3.5             1
# 1449        GB        LV                  1          1.0             0
#
#       _correct
# 1436         1
# 1437         1
# 1438         1
# 1439         0
# 1440         0
# 1441         0
# 1442         1
# 1443         0
# 1444         0
# 1445         1
# 1446         1
# 1447         1
# 1448         0
# 1449         0

# %%
this_season[this_season['week']<5]['coverage_flg_pred'].mean()
# Out:
# 0.203125

# %%
this_season[this_season['week']<4]['coverage_flg'].mean()
# Out:
# 0.3958333333333333

# %%
poly = model['poly']

# %%
feats_after_var = [poly.get_feature_names_out()[i] for i in model['VarianceThreshold'].get_support(indices=True)]

# %%
first_45 = [feats_after_var[i] for i in model['selector'].get_support(indices=True)]

# %%
last_5 = [first_45[i] for i in model['selector2'].get_support(indices=True)]

# %%
last_5
# Out:
# ['surface_grass*away_surface_astroturf',
#  'surface_grass*away_surface_astroturf^2',
#  'surface_grass*away_surface_astroturf away_rushing_epa',
#  'away_surface_astroturf diff_special_teams_tds',
#  'home_completions away_cumemeanresult_shift1']

# %%
'''
166+ features
Downselected by correlation to 30ish
Polynomial interactions calculated to 300+
Downselected by f-value of ANOVA to 45
Forward selected to final 5 by perceptron
These are the final 5 features. All are interaction features.
cumemeanresult_diff away_fantasy_points and home_pacr each appear in multiple features
'''
# Out:
# '\n166+ features\nDownselected by correlation to 30ish\nPolynomial interactions calculated to 300+\nDownselected by f-value of ANOVA to 45\nForward selected to final 5 by perceptron\nThese are the final 5 features. All are interaction features.\ncumemeanresult_diff away_fantasy_points and home_pacr each appear in multiple features\n'

# %%
import joblib

joblib.dump(model,'../artifacts/model.joblib')
# Out:
# ['../artifacts/model.joblib']
