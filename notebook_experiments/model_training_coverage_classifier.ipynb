# %%
#pip install torch --index-url https://download.pytorch.org/whl/cu118
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split


data = pd.read_csv("../data/model_data.csv")

# %%
home_surfaces = data[[i for i in data.columns if ('surface_' in i)&('away_' not in i)]].copy()
away_surfaces = data[[i for i in data.columns if ('surface_' in i)&('away_' in i)]].copy()

surface_interactions = pd.DataFrame()
for col in home_surfaces.columns:
    for acol in away_surfaces.columns:
        surface_interactions[f"{col}*{acol}"] = (
            home_surfaces[col]*away_surfaces[acol]
        )

sit = surface_interactions.T

surface_interactions = sit[sit.sum(axis=1)>30].T

data[list(surface_interactions.columns)] = surface_interactions

data['coverage_flg'] = np.where(data['coverage']>0,1,0)

# %%
this_season = data[data['season']==2023].copy()

model_data = data[data['season']<2023].copy()
model_data = model_data[model_data['coverage']!=0].copy()

exclusions = ['away_team','home_team','away_score','home_score','result','season','coverage','coverage_flg']

first_features = [
    i for i in model_data.columns if 
    (i not in exclusions)&
    ('_team_id_' not in i)&
    ('2pt' not in i)
]
target = 'coverage_flg'
spread = 'spread_line'
result = 'result'

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(model_data[first_features],model_data[target],
                                           test_size=.2,random_state=42,shuffle=True)

# %%
corr = pd.concat([Xtrain,ytrain],axis=1).corr(numeric_only=True,method='pearson')[target].sort_values()
corr.sort_values(ascending=False)
feats_used = corr[(abs(corr)>.04)&(abs(corr)<1)]
features = [i for i in feats_used.index if i != target]

# %%
pd.set_option("display.max_rows",164)
corr.sort_values(ascending=False)
# Out:
# coverage_flg                                1.000000e+00
# week                                        5.472462e-02
# away_cumemeanresult_shift1                  5.445879e-02
# away_rushing_fumbles                        5.046088e-02
# home_receiving_fumbles                      4.751360e-02
# home_receiving_tds                          4.650585e-02
# home_pacr                                   4.369584e-02
# away_special_teams_tds                      4.165177e-02
# diff_passing_tds                            4.061924e-02
# away_rushing_first_downs                    4.057666e-02
# surface_matrixturf*away_surface_grass       3.859767e-02
# away_rushing_yards                          3.857847e-02
# diff_receiving_tds                          3.705187e-02
# away_rushing_epa                            3.638679e-02
# away_fantasy_points                         3.566433e-02
# home_carries                                3.547623e-02
# diff_sack_fumbles                           3.538471e-02
# diff_passing_epa                            3.524355e-02
# surface_matrixturf                          3.505804e-02
# diff_receiving_yards_after_catch            3.372505e-02
# home_rushing_yards                          3.198105e-02
# diff_sack_fumbles_lost                      3.086534e-02
# home_passing_tds                            3.082198e-02
# away_rushing_fumbles_lost                   3.027217e-02
# home_passing_epa                            2.962831e-02
# diff_receiving_fumbles                      2.834082e-02
# diff_receiving_first_downs                  2.797384e-02
# roof_outdoors                               2.704524e-02
# home_receiving_yards_after_catch            2.627251e-02
# away_carries                                2.484134e-02
# surface_grass*away_surface_grass            2.467493e-02
# away_receiving_fumbles_lost                 2.416646e-02
# diff_pacr                                   2.403380e-02
# home_rushing_fumbles                        2.391822e-02
# away_wopr                                   2.360856e-02
# away_surface_grass                          2.331187e-02
# away_air_yards_share                        2.231207e-02
# away_target_share                           2.217949e-02
# away_receiving_air_yards                    2.209392e-02
# away_fantasy_points_ppr                     2.163409e-02
# diff_passing_yards_after_catch              2.068412e-02
# surface_grass                               1.999498e-02
# diff_receiving_epa                          1.942000e-02
# home_fantasy_points                         1.925333e-02
# away_surface_fieldturf                      1.871951e-02
# home_fantasy_points_ppr                     1.799186e-02
# home_sack_fumbles                           1.788244e-02
# home_rushing_first_downs                    1.668932e-02
# home_receiving_fumbles_lost                 1.638061e-02
# away_rushing_tds                            1.551053e-02
# away_interceptions                          1.437852e-02
# roof_dome                                   1.411739e-02
# surface_grass*away_surface_fieldturf        1.326946e-02
# home_rushing_epa                            1.250479e-02
# away_pacr                                   1.089362e-02
# home_receiving_epa                          1.068215e-02
# diff_receptions                             1.026713e-02
# surface_fieldturf*away_surface_fieldturf    9.252915e-03
# away_receiving_fumbles                      8.285923e-03
# diff_racr                                   7.823355e-03
# diff_receiving_yards                        7.372628e-03
# diff_carries                                7.334346e-03
# home_receiving_first_downs                  6.196628e-03
# diff_sack_yards                             5.082860e-03
# home_passing_yards_after_catch              4.694091e-03
# away_surface_sportturf                      4.605688e-03
# surface_grass*away_surface_matrixturf       4.605688e-03
# diff_games                                  4.252003e-03
# diff_targets                                4.011454e-03
# away_passing_air_yards                      1.842993e-03
# away_roof_dome                              2.668952e-17
# home_receiving_yards                       -9.283655e-04
# home_targets                               -9.691654e-04
# home_racr                                  -1.448178e-03
# diff_passing_first_downs                   -1.763509e-03
# diff_fantasy_points_ppr                    -2.919159e-03
# surface_sportturf*away_surface_grass       -3.554257e-03
# diff_passing_yards                         -3.589182e-03
# home_receptions                            -3.719668e-03
# home_sack_yards                            -4.126931e-03
# away_receiving_tds                         -4.134140e-03
# surface_astroturf                          -4.226712e-03
# diff_rushing_yards                         -4.759352e-03
# surface_fieldturf*away_surface_grass       -4.801594e-03
# away_roof_open                             -4.921987e-03
# away_roof_outdoors                         -5.036565e-03
# surface_grass*away_surface_sportturf       -5.695918e-03
# away_targets                               -6.690675e-03
# surface_sportturf                          -7.048984e-03
# diff_sacks                                 -7.645823e-03
# diff_receiving_fumbles_lost                -8.406944e-03
# home_target_share                          -9.983574e-03
# home_rushing_fumbles_lost                  -1.062988e-02
# surface_astroturf*away_surface_grass       -1.069652e-02
# diff_completions                           -1.123003e-02
# away_receiving_yards                       -1.151770e-02
# home_receiving_air_yards                   -1.172051e-02
# home_sack_fumbles_lost                     -1.182259e-02
# diff_fantasy_points                        -1.236519e-02
# away_racr                                  -1.319604e-02
# away_sack_yards                            -1.336665e-02
# away_passing_first_downs                   -1.366801e-02
# away_completions                           -1.391975e-02
# away_passing_yards                         -1.401249e-02
# home_interceptions                         -1.421083e-02
# away_sacks                                 -1.442651e-02
# away_attempts                              -1.470668e-02
# home_passing_first_downs                   -1.584070e-02
# away_receiving_epa                         -1.604311e-02
# home_wopr                                  -1.626567e-02
# diff_rushing_first_downs                   -1.688874e-02
# diff_rushing_epa                           -1.713666e-02
# away_passing_epa                           -1.864142e-02
# away_receptions                            -1.879231e-02
# home_sacks                                 -1.882633e-02
# home_passing_yards                         -1.928849e-02
# diff_rushing_fumbles                       -2.119627e-02
# away_receiving_yards_after_catch           -2.165138e-02
# diff_rushing_fumbles_lost                  -2.201606e-02
# diff_target_share                          -2.257627e-02
# home_games                                 -2.358439e-02
# away_passing_yards_after_catch             -2.397438e-02
# diff_receiving_air_yards                   -2.420582e-02
# away_passing_tds                           -2.423125e-02
# surface_fieldturf                          -2.442389e-02
# diff_interceptions                         -2.468161e-02
# home_rushing_tds                           -2.476413e-02
# roof_open                                  -2.545400e-02
# diff_attempts                              -2.569586e-02
# away_sack_fumbles                          -2.635626e-02
# home_air_yards_share                       -2.708927e-02
# diff_wopr                                  -2.801790e-02
# away_games                                 -2.847267e-02
# diff_rushing_tds                           -2.857777e-02
# home_completions                           -2.998081e-02
# diff_passing_air_yards                     -3.258334e-02
# away_receiving_first_downs                 -3.380434e-02
# diff_air_yards_share                       -3.454512e-02
# home_special_teams_tds                     -3.698253e-02
# away_surface_matrixturf                    -3.747401e-02
# home_passing_air_yards                     -4.279524e-02
# away_sack_fumbles_lost                     -4.440477e-02
# spread_line                                -4.829732e-02
# home_attempts                              -4.973927e-02
# home_cumemeanresult_shift1                 -4.992748e-02
# surface_grass*away_surface_astroturf       -5.568158e-02
# away_surface_astroturf                     -5.707158e-02
# diff_special_teams_tds                     -5.964480e-02
# cumemeanresult_diff                        -7.670912e-02
# surface_astroplay                                    NaN
# surface_dessograss                                   NaN
# away_surface_astroplay                               NaN
# away_surface_dessograss                              NaN
# Name: coverage_flg, dtype: float64

# %%
features
# Out:
# ['cumemeanresult_diff',
#  'diff_special_teams_tds',
#  'away_surface_astroturf',
#  'surface_grass*away_surface_astroturf',
#  'home_cumemeanresult_shift1',
#  'home_attempts',
#  'spread_line',
#  'away_sack_fumbles_lost',
#  'home_passing_air_yards',
#  'away_rushing_first_downs',
#  'diff_passing_tds',
#  'away_special_teams_tds',
#  'home_pacr',
#  'home_receiving_tds',
#  'home_receiving_fumbles',
#  'away_rushing_fumbles',
#  'away_cumemeanresult_shift1',
#  'week']

# %%
ytrain.mean()
# Out:
# 0.477124183006536

# %%
Xtrain,Xtest,ytrain,ytest,strain,stest=train_test_split(
    model_data[features],model_data[target],
    ((model_data['season']-min(model_data['season']))/(max(model_data['season'])-min(model_data['season'])))*0+1,
    test_size=.2,random_state=42,shuffle=True)

# %%
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures


from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SequentialFeatureSelector

from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
inner = SGDClassifier(loss='perceptron',penalty='l2',alpha=.0001,
                      fit_intercept=False,
                      early_stopping=True,shuffle=True,
                      validation_fraction=.1,n_iter_no_change=25,random_state=42)

inner = KNeighborsClassifier(n_neighbors=60,weights='distance')
#inner = RandomForestClassifier(random_state=42,n_estimators=35,max_depth=4)
model = Pipeline(steps=[
    ('poly',PolynomialFeatures(degree=2,interaction_only=False,include_bias=True)),
    ('VarianceThreshold',VarianceThreshold()),
    ('scaler',StandardScaler()),
    ('selector',SelectKBest(k=15)),
    #('selector',SequentialFeatureSelector(estimator=inner)),
    ('learner',inner
    )
]).fit(Xtrain.fillna(0),ytrain)#,learner__sample_weight=strain)

coverage_flg_pred = pd.Series(model.predict(Xtest.fillna(0)),Xtest.index)
coverage_flg_fit = pd.Series(model.predict(Xtrain.fillna(0)),Xtrain.index)

# %%
print("Training: ")
result = pd.DataFrame()
result[target] = ytrain
result[target+'_pred'] = coverage_flg_fit

result['outcome'] = np.where(
    (result['coverage_flg']==0)&(result['coverage_flg_pred']==0),'TN',
    np.where(
    (result['coverage_flg']==1)&(result['coverage_flg_pred']==1),'TP',
    np.where(
    (result['coverage_flg']==1)&(result['coverage_flg_pred']==0),'FN','FP')))

result['correct'] = np.where(result['outcome'].str[0]=='T','T','F')
result['cnt']=1
conf = result.groupby(['outcome'])['cnt'].sum()
acc = result.groupby(['correct'])['cnt'].sum()

if 'FN' in conf.index:
    print(conf)
    print(acc)
    print('recall: ',conf['TP']/(conf['TP']+conf['FN']))
    print('precision: ',conf['TP']/(conf['TP']+conf['FP']))
    print('selectivity: ',conf['TN']/(conf['TN']+conf['FP']))
    print('neg pred val: ',conf['TN']/(conf['TN']+conf['FN']))
    print('accuracy: ',acc['T']/(acc['T']+acc['F']))

print("Test: ")
result = pd.DataFrame()
result[target] = ytest
result[target+'_pred'] = coverage_flg_pred

result['outcome'] = np.where(
    (result['coverage_flg']==0)&(result['coverage_flg_pred']==0),'TN',
    np.where(
    (result['coverage_flg']==1)&(result['coverage_flg_pred']==1),'TP',
    np.where(
    (result['coverage_flg']==1)&(result['coverage_flg_pred']==0),'FN','FP')))
result['correct'] = np.where(result['outcome'].str[0]=='T','T','F')
result['cnt']=1
conf = result.groupby(['outcome'])['cnt'].sum()
acc = result.groupby(['correct'])['cnt'].sum()
print(conf)
print(acc)
print('recall: ',conf['TP']/(conf['TP']+conf['FN']))
print('precision: ',conf['TP']/(conf['TP']+conf['FP']))
print('selectivity: ',conf['TN']/(conf['TN']+conf['FP']))
print('neg pred val: ',conf['TN']/(conf['TN']+conf['FN']))
print('accuracy: ',acc['T']/(acc['T']+acc['F']))
# Out:
# Training:
# Test:
# outcome
# FN    81
# FP    46
# TN    94
# TP    47
# Name: cnt, dtype: int64
# correct
# F    127
# T    141
# Name: cnt, dtype: int64
# recall:  0.3671875
# precision:  0.5053763440860215
# selectivity:  0.6714285714285714
# neg pred val:  0.5371428571428571
# accuracy:  0.5261194029850746

# %%
allY = pd.concat([ytrain,ytest])
allX = pd.concat([Xtrain,Xtest])

model.fit(allX.fillna(0),allY)
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures()),
#                 ('VarianceThreshold', VarianceThreshold()),
#                 ('scaler', StandardScaler()), ('selector', SelectKBest(k=15)),
#                 ('learner',
#                  KNeighborsClassifier(n_neighbors=60, weights='distance'))])

# %%
result.mean(numeric_only=True)
# Out:
# coverage_flg         0.477612
# coverage_flg_pred    0.347015
# cnt                  1.000000
# dtype: float64

# %%
this_seasonX = this_season[features].copy()
this_season_coverage_flg_prediction = pd.Series(
    model.predict(this_seasonX.fillna(0)),
    this_seasonX.index)
this_season['coverage_flg_pred'] = this_season_coverage_flg_prediction

# %%
this_season[this_season['week']==1][['away_team','home_team','coverage_flg_pred']]
# Out:
#      away_team home_team  coverage_flg_pred
# 1372       DET        KC                  0
# 1373       CAR       ATL                  0
# 1374       HOU       BAL                  0
# 1375       CIN       CLE                  0
# 1376       JAX       IND                  1
# 1377        TB       MIN                  0
# 1378       TEN        NO                  1
# 1379        SF       PIT                  0
# 1380       ARI       WAS                  0
# 1381        GB       CHI                  1
# 1382        LV       DEN                  0
# 1383       MIA       LAC                  0
# 1384       PHI        NE                  0
# 1385        LA       SEA                  1
# 1386       DAL       NYG                  1
# 1387       BUF       NYJ                  1

# %%
this_season[this_season['week']==2][['away_team','home_team','coverage_flg_pred']]
# Out:
#      away_team home_team  coverage_flg_pred
# 1388       MIN       PHI                  0
# 1389        GB       ATL                  1
# 1390        LV       BUF                  1
# 1391       BAL       CIN                  1
# 1392       SEA       DET                  0
# 1393       IND       HOU                  0
# 1394        KC       JAX                  0
# 1395       CHI        TB                  0
# 1396       LAC       TEN                  1
# 1397       NYG       ARI                  0
# 1398        SF        LA                  1
# 1399       NYJ       DAL                  0
# 1400       WAS       DEN                  1
# 1401       MIA        NE                  1
# 1402        NO       CAR                  1
# 1403       CLE       PIT                  1

# %%
this_season[this_season['week']==3][['away_team','home_team','coverage_flg_pred']]
# Out:
#      away_team home_team  coverage_flg_pred
# 1404       NYG        SF                  0
# 1405       IND       BAL                  0
# 1406       TEN       CLE                  0
# 1407       ATL       DET                  1
# 1408        NO        GB                  0
# 1409       HOU       JAX                  0
# 1410       DEN       MIA                  0
# 1411       LAC       MIN                  0
# 1412        NE       NYJ                  0
# 1413       BUF       WAS                  0
# 1414       CAR       SEA                  0
# 1415       DAL       ARI                  1
# 1416       CHI        KC                  0
# 1417       PIT        LV                  0
# 1418       PHI        TB                  1
# 1419        LA       CIN                  1

# %%
this_season[this_season['week']==4][['away_team','home_team','coverage_flg_pred']]
# Out:
#      away_team home_team  coverage_flg_pred
# 1420       DET        GB                  0
# 1421       ATL       JAX                  1
# 1422       MIA       BUF                  0
# 1423       MIN       CAR                  0
# 1424       DEN       CHI                  1
# 1425       BAL       CLE                  0
# 1426       PIT       HOU                  0
# 1427        LA       IND                  0
# 1428        TB        NO                  0
# 1429       WAS       PHI                  0
# 1430       CIN       TEN                  0
# 1431        LV       LAC                  0
# 1432        NE       DAL                  0
# 1433       ARI        SF                  0
# 1434        KC       NYJ                  1
# 1435       SEA       NYG                  1

# %%
this_season[this_season['week']<4]['coverage_flg_pred'].mean()
# Out:
# 0.3958333333333333

# %%
this_season[this_season['week']<4]['coverage_flg'].mean()
# Out:
# 0.3958333333333333

# %%
this_season['coverage_flg']
# Out:
# 1372    0
# 1373    1
# 1374    1
# 1375    1
# 1376    0
#        ..
# 1639    0
# 1640    0
# 1641    0
# 1642    0
# 1643    0
# Name: coverage_flg, Length: 272, dtype: int32
